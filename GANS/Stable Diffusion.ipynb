# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
import tensorflow as tf
import keras_cv
from tensorflow import keras
keras_cv.__version__
# Out:
# '0.3.4'

# %%
# Loading a stable diffusion:
model = keras_cv.models.StableDiffusion(img_width=256, img_height=256)
# Out:
# WARNING:tensorflow:From /home/impureking/miniconda3/envs/TensorFlowV2/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/impureking/miniconda3/envs/TensorFlowV2/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
from matplotlib import pyplot as plt

images = model.text_to_image("Lol", batch_size=1)
# Out:
# 25/25 [==============================] - 12s 213ms/step

# %%
def plot_images(images):
    plt.figure()
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")


plot_images(images)

# %%
model.decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 32, 32, 4)         0
#
#  padded_conv2d_84 (PaddedCon  (None, 32, 32, 4)        20
#  v2D)
#
#  padded_conv2d_85 (PaddedCon  (None, 32, 32, 512)      18944
#  v2D)
#
#  resnet_block (ResnetBlock)  (None, 32, 32, 512)       4721664
#
#  attention_block (AttentionB  (None, 32, 32, 512)      1051648
#  lock)
#
#  resnet_block_1 (ResnetBlock  (None, 32, 32, 512)      4721664
#  )
#
#  resnet_block_2 (ResnetBlock  (None, 32, 32, 512)      4721664
#  )
#
#  resnet_block_3 (ResnetBlock  (None, 32, 32, 512)      4721664
#  )
#
#  resnet_block_4 (ResnetBlock  (None, 32, 32, 512)      4721664
#  )
#
#  up_sampling2d_3 (UpSampling  (None, 64, 64, 512)      0
#  2D)
#
#  padded_conv2d_100 (PaddedCo  (None, 64, 64, 512)      2359808
#  nv2D)
#
#  resnet_block_5 (ResnetBlock  (None, 64, 64, 512)      4721664
#  )
#
#  resnet_block_6 (ResnetBlock  (None, 64, 64, 512)      4721664
#  )
#
#  resnet_block_7 (ResnetBlock  (None, 64, 64, 512)      4721664
#  )
#
#  up_sampling2d_4 (UpSampling  (None, 128, 128, 512)    0
#  2D)
#
#  padded_conv2d_107 (PaddedCo  (None, 128, 128, 512)    2359808
#  nv2D)
#
#  resnet_block_8 (ResnetBlock  (None, 128, 128, 256)    1902848
#  )
#
#  resnet_block_9 (ResnetBlock  (None, 128, 128, 256)    1181184
#  )
#
#  resnet_block_10 (ResnetBloc  (None, 128, 128, 256)    1181184
#  k)
#
#  up_sampling2d_5 (UpSampling  (None, 256, 256, 256)    0
#  2D)
#
#  padded_conv2d_114 (PaddedCo  (None, 256, 256, 256)    590080
#  nv2D)
#
#  resnet_block_11 (ResnetBloc  (None, 256, 256, 128)    476288
#  k)
#
#  resnet_block_12 (ResnetBloc  (None, 256, 256, 128)    295680
#  k)
#
#  resnet_block_13 (ResnetBloc  (None, 256, 256, 128)    295680
#  k)
#
#  group_normalization_90 (Gro  (None, 256, 256, 128)    256
#  upNormalization)
#
#  activation_68 (Activation)  (None, 256, 256, 128)     0
#
#  padded_conv2d_121 (PaddedCo  (None, 256, 256, 3)      3459
#  nv2D)
#
# =================================================================
# Total params: 49,490,199
# Trainable params: 49,490,199
# Non-trainable params: 0
# _________________________________________________________________
