# %%
from model import build_generator, generate_faces

# %%
model = build_generator(128)
# Out:
# /home/workstation/miniconda3/envs/TensorFlow/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 36864)             4755456
#
#  batch_normalization (BatchN  (None, 36864)            147456
#  ormalization)
#
#  re_lu (ReLU)                (None, 36864)             0
#
#  reshape (Reshape)           (None, 6, 6, 1024)        0
#
#  conv2d_transpose (Conv2DTra  (None, 12, 12, 512)      13107200
#  nspose)
#
#  batch_normalization_1 (Batc  (None, 12, 12, 512)      2048
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 12, 12, 512)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 24, 24, 256)      3276800
#  ranspose)
#
#  batch_normalization_2 (Batc  (None, 24, 24, 256)      1024
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 24, 24, 256)       0
#
#  conv2d_transpose_2 (Conv2DT  (None, 48, 48, 128)      294912
#  ranspose)
#
#  batch_normalization_3 (Batc  (None, 48, 48, 128)      512
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 48, 48, 128)       0
#
#  conv2d_transpose_3 (Conv2DT  (None, 96, 96, 3)        3456
#  ranspose)
#
#  activation (Activation)     (None, 96, 96, 3)         0
#
# =================================================================
# Total params: 21,588,864
# Trainable params: 21,513,344
# Non-trainable params: 75,520
# _________________________________________________________________

# %%
model.load_weights('generator_weights-test.h5')

# %%
# Generating sample images:
generate_faces(model)
